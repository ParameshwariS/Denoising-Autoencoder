# %% [markdown]
# #**DEEP LEARNING - Denoising Autoencoders for Tamil Characters**

# %% [markdown]
# ##**Parameshwari S - CB.SC.I5DAS18026**

# %% [markdown]
# ### **Uploading the data**

# %%
# !pip install Wand
# !apt-get install libmagickwand-dev
# Out:
# Collecting Wand
#   Downloading Wand-0.6.7-py2.py3-none-any.whl (139 kB)
#      |████████████████████████████████| 139 kB 15.4 MB/s
# Installing collected packages: Wand
# Successfully installed Wand-0.6.7
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-noto-mono ghostscript gir1.2-freedesktop
#   gir1.2-gdkpixbuf-2.0 gir1.2-rsvg-2.0 gsfonts imagemagick-6-common
#   libcairo-script-interpreter2 libcairo2-dev libcupsfilters1 libcupsimage2
#   libdjvulibre-dev libdjvulibre-text libdjvulibre21 libgdk-pixbuf2.0-dev
#   libgs9 libgs9-common libijs-0.35 libjbig2dec0 liblcms2-dev liblqr-1-0
#   liblqr-1-0-dev libmagickcore-6-arch-config libmagickcore-6-headers
#   libmagickcore-6.q16-3 libmagickcore-6.q16-3-extra libmagickcore-6.q16-dev
#   libmagickwand-6-headers libmagickwand-6.q16-3 libmagickwand-6.q16-dev
#   libpixman-1-dev librsvg2-dev libwmf-dev libwmf0.2-7 libxcb-shm0-dev
#   poppler-data
# Suggested packages:
#   fonts-noto ghostscript-x libcairo2-doc inkscape libjxr-tools librsvg2-doc
#   libwmf-doc libwmf0.2-7-gtk poppler-utils fonts-japanese-mincho
#   | fonts-ipafont-mincho fonts-japanese-gothic | fonts-ipafont-gothic
#   fonts-arphic-ukai fonts-arphic-uming fonts-nanum
# The following NEW packages will be installed:
#   fonts-droid-fallback fonts-noto-mono ghostscript gir1.2-freedesktop
#   gir1.2-gdkpixbuf-2.0 gir1.2-rsvg-2.0 gsfonts imagemagick-6-common
#   libcairo-script-interpreter2 libcairo2-dev libcupsfilters1 libcupsimage2
#   libdjvulibre-dev libdjvulibre-text libdjvulibre21 libgdk-pixbuf2.0-dev
#   libgs9 libgs9-common libijs-0.35 libjbig2dec0 liblcms2-dev liblqr-1-0
#   liblqr-1-0-dev libmagickcore-6-arch-config libmagickcore-6-headers
#   libmagickcore-6.q16-3 libmagickcore-6.q16-3-extra libmagickcore-6.q16-dev
#   libmagickwand-6-headers libmagickwand-6.q16-3 libmagickwand-6.q16-dev
#   libmagickwand-dev libpixman-1-dev librsvg2-dev libwmf-dev libwmf0.2-7
#   libxcb-shm0-dev poppler-data
# 0 upgraded, 38 newly installed, 0 to remove and 37 not upgraded.
# Need to get 31.0 MB of archives.
# After this operation, 91.0 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-droid-fallback all 1:6.0.1r16-1.1 [1,805 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 imagemagick-6-common all 8:6.9.7.4+dfsg-16ubuntu6.11 [60.2 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagickcore-6-arch-config amd64 8:6.9.7.4+dfsg-16ubuntu6.11 [25.2 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagickcore-6-headers all 8:6.9.7.4+dfsg-16ubuntu6.11 [47.2 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 liblqr-1-0 amd64 0.4.2-2.1 [27.7 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagickcore-6.q16-3 amd64 8:6.9.7.4+dfsg-16ubuntu6.11 [1,619 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagickwand-6-headers all 8:6.9.7.4+dfsg-16ubuntu6.11 [10.6 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagickwand-6.q16-3 amd64 8:6.9.7.4+dfsg-16ubuntu6.11 [294 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdjvulibre-text all 3.5.27.1-8ubuntu0.4 [49.4 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdjvulibre21 amd64 3.5.27.1-8ubuntu0.4 [561 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 libwmf0.2-7 amd64 0.2.8.4-12 [150 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagickcore-6.q16-3-extra amd64 8:6.9.7.4+dfsg-16ubuntu6.11 [62.4 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdjvulibre-dev amd64 3.5.27.1-8ubuntu0.4 [2,382 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 liblcms2-dev amd64 2.9-1ubuntu0.1 [9,096 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 liblqr-1-0-dev amd64 0.4.2-2.1 [69.1 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-freedesktop amd64 1.56.1-1 [9,080 B]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-gdkpixbuf-2.0 amd64 2.36.11-2 [7,748 B]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gir1.2-rsvg-2.0 amd64 2.40.20-2ubuntu0.2 [3,764 B]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdk-pixbuf2.0-dev amd64 2.36.11-2 [46.8 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcairo-script-interpreter2 amd64 1.15.10-2ubuntu0.1 [53.5 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpixman-1-dev amd64 0.34.0-2 [244 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-shm0-dev amd64 1.13-2~ubuntu18.04 [6,684 B]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcairo2-dev amd64 1.15.10-2ubuntu0.1 [626 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 librsvg2-dev amd64 2.40.20-2ubuntu0.2 [10.7 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic/main amd64 libwmf-dev amd64 0.2.8.4-12 [172 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagickcore-6.q16-dev amd64 8:6.9.7.4+dfsg-16ubuntu6.11 [974 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagickwand-6.q16-dev amd64 8:6.9.7.4+dfsg-16ubuntu6.11 [290 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagickwand-dev all 8:6.9.7.4+dfsg-16ubuntu6.11 [1,372 B]
# Get:29 http://archive.ubuntu.com/ubuntu bionic/main amd64 poppler-data all 0.4.8-2 [1,479 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-noto-mono all 20171026-2 [75.5 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcupsimage2 amd64 2.2.7-1ubuntu2.8 [18.6 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic/main amd64 libijs-0.35 amd64 0.35-13 [15.5 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjbig2dec0 amd64 0.13-6 [55.9 kB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgs9-common all 9.26~dfsg+0-0ubuntu0.18.04.14 [5,092 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgs9 amd64 9.26~dfsg+0-0ubuntu0.18.04.14 [2,265 kB]
# Get:36 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 ghostscript amd64 9.26~dfsg+0-0ubuntu0.18.04.14 [51.3 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic/main amd64 gsfonts all 1:8.11+urwcyr1.0.7~pre44-4.4 [3,120 kB]
# Get:38 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcupsfilters1 amd64 1.20.2-0ubuntu3.1 [108 kB]
# Fetched 31.0 MB in 1s (57.1 MB/s)
# Extracting templates from packages: 100%
# Selecting previously unselected package fonts-droid-fallback.
# (Reading database ... 155219 files and directories currently installed.)
# Preparing to unpack .../00-fonts-droid-fallback_1%3a6.0.1r16-1.1_all.deb ...
# Unpacking fonts-droid-fallback (1:6.0.1r16-1.1) ...
# Selecting previously unselected package imagemagick-6-common.
# Preparing to unpack .../01-imagemagick-6-common_8%3a6.9.7.4+dfsg-16ubuntu6.11_all.deb ...
# Unpacking imagemagick-6-common (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Selecting previously unselected package libmagickcore-6-arch-config:amd64.
# Preparing to unpack .../02-libmagickcore-6-arch-config_8%3a6.9.7.4+dfsg-16ubuntu6.11_amd64.deb ...
# Unpacking libmagickcore-6-arch-config:amd64 (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Selecting previously unselected package libmagickcore-6-headers.
# Preparing to unpack .../03-libmagickcore-6-headers_8%3a6.9.7.4+dfsg-16ubuntu6.11_all.deb ...
# Unpacking libmagickcore-6-headers (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Selecting previously unselected package liblqr-1-0:amd64.
# Preparing to unpack .../04-liblqr-1-0_0.4.2-2.1_amd64.deb ...
# Unpacking liblqr-1-0:amd64 (0.4.2-2.1) ...
# Selecting previously unselected package libmagickcore-6.q16-3:amd64.
# Preparing to unpack .../05-libmagickcore-6.q16-3_8%3a6.9.7.4+dfsg-16ubuntu6.11_amd64.deb ...
# Unpacking libmagickcore-6.q16-3:amd64 (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Selecting previously unselected package libmagickwand-6-headers.
# Preparing to unpack .../06-libmagickwand-6-headers_8%3a6.9.7.4+dfsg-16ubuntu6.11_all.deb ...
# Unpacking libmagickwand-6-headers (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Selecting previously unselected package libmagickwand-6.q16-3:amd64.
# Preparing to unpack .../07-libmagickwand-6.q16-3_8%3a6.9.7.4+dfsg-16ubuntu6.11_amd64.deb ...
# Unpacking libmagickwand-6.q16-3:amd64 (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Selecting previously unselected package libdjvulibre-text.
# Preparing to unpack .../08-libdjvulibre-text_3.5.27.1-8ubuntu0.4_all.deb ...
# Unpacking libdjvulibre-text (3.5.27.1-8ubuntu0.4) ...
# Selecting previously unselected package libdjvulibre21:amd64.
# Preparing to unpack .../09-libdjvulibre21_3.5.27.1-8ubuntu0.4_amd64.deb ...
# Unpacking libdjvulibre21:amd64 (3.5.27.1-8ubuntu0.4) ...
# Selecting previously unselected package libwmf0.2-7:amd64.
# Preparing to unpack .../10-libwmf0.2-7_0.2.8.4-12_amd64.deb ...
# Unpacking libwmf0.2-7:amd64 (0.2.8.4-12) ...
# Selecting previously unselected package libmagickcore-6.q16-3-extra:amd64.
# Preparing to unpack .../11-libmagickcore-6.q16-3-extra_8%3a6.9.7.4+dfsg-16ubuntu6.11_amd64.deb ...
# Unpacking libmagickcore-6.q16-3-extra:amd64 (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Selecting previously unselected package libdjvulibre-dev:amd64.
# Preparing to unpack .../12-libdjvulibre-dev_3.5.27.1-8ubuntu0.4_amd64.deb ...
# Unpacking libdjvulibre-dev:amd64 (3.5.27.1-8ubuntu0.4) ...
# Selecting previously unselected package liblcms2-dev:amd64.
# Preparing to unpack .../13-liblcms2-dev_2.9-1ubuntu0.1_amd64.deb ...
# Unpacking liblcms2-dev:amd64 (2.9-1ubuntu0.1) ...
# Selecting previously unselected package liblqr-1-0-dev:amd64.
# Preparing to unpack .../14-liblqr-1-0-dev_0.4.2-2.1_amd64.deb ...
# Unpacking liblqr-1-0-dev:amd64 (0.4.2-2.1) ...
# Selecting previously unselected package gir1.2-freedesktop:amd64.
# Preparing to unpack .../15-gir1.2-freedesktop_1.56.1-1_amd64.deb ...
# Unpacking gir1.2-freedesktop:amd64 (1.56.1-1) ...
# Selecting previously unselected package gir1.2-gdkpixbuf-2.0:amd64.
# Preparing to unpack .../16-gir1.2-gdkpixbuf-2.0_2.36.11-2_amd64.deb ...
# Unpacking gir1.2-gdkpixbuf-2.0:amd64 (2.36.11-2) ...
# Selecting previously unselected package gir1.2-rsvg-2.0:amd64.
# Preparing to unpack .../17-gir1.2-rsvg-2.0_2.40.20-2ubuntu0.2_amd64.deb ...
# Unpacking gir1.2-rsvg-2.0:amd64 (2.40.20-2ubuntu0.2) ...
# Selecting previously unselected package libgdk-pixbuf2.0-dev.
# Preparing to unpack .../18-libgdk-pixbuf2.0-dev_2.36.11-2_amd64.deb ...
# Unpacking libgdk-pixbuf2.0-dev (2.36.11-2) ...
# Selecting previously unselected package libcairo-script-interpreter2:amd64.
# Preparing to unpack .../19-libcairo-script-interpreter2_1.15.10-2ubuntu0.1_amd64.deb ...
# Unpacking libcairo-script-interpreter2:amd64 (1.15.10-2ubuntu0.1) ...
# Selecting previously unselected package libpixman-1-dev:amd64.
# Preparing to unpack .../20-libpixman-1-dev_0.34.0-2_amd64.deb ...
# Unpacking libpixman-1-dev:amd64 (0.34.0-2) ...
# Selecting previously unselected package libxcb-shm0-dev:amd64.
# Preparing to unpack .../21-libxcb-shm0-dev_1.13-2~ubuntu18.04_amd64.deb ...
# Unpacking libxcb-shm0-dev:amd64 (1.13-2~ubuntu18.04) ...
# Selecting previously unselected package libcairo2-dev:amd64.
# Preparing to unpack .../22-libcairo2-dev_1.15.10-2ubuntu0.1_amd64.deb ...
# Unpacking libcairo2-dev:amd64 (1.15.10-2ubuntu0.1) ...
# Selecting previously unselected package librsvg2-dev:amd64.
# Preparing to unpack .../23-librsvg2-dev_2.40.20-2ubuntu0.2_amd64.deb ...
# Unpacking librsvg2-dev:amd64 (2.40.20-2ubuntu0.2) ...
# Selecting previously unselected package libwmf-dev.
# Preparing to unpack .../24-libwmf-dev_0.2.8.4-12_amd64.deb ...
# Unpacking libwmf-dev (0.2.8.4-12) ...
# Selecting previously unselected package libmagickcore-6.q16-dev:amd64.
# Preparing to unpack .../25-libmagickcore-6.q16-dev_8%3a6.9.7.4+dfsg-16ubuntu6.11_amd64.deb ...
# Unpacking libmagickcore-6.q16-dev:amd64 (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Selecting previously unselected package libmagickwand-6.q16-dev:amd64.
# Preparing to unpack .../26-libmagickwand-6.q16-dev_8%3a6.9.7.4+dfsg-16ubuntu6.11_amd64.deb ...
# Unpacking libmagickwand-6.q16-dev:amd64 (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Selecting previously unselected package libmagickwand-dev.
# Preparing to unpack .../27-libmagickwand-dev_8%3a6.9.7.4+dfsg-16ubuntu6.11_all.deb ...
# Unpacking libmagickwand-dev (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Selecting previously unselected package poppler-data.
# Preparing to unpack .../28-poppler-data_0.4.8-2_all.deb ...
# Unpacking poppler-data (0.4.8-2) ...
# Selecting previously unselected package fonts-noto-mono.
# Preparing to unpack .../29-fonts-noto-mono_20171026-2_all.deb ...
# Unpacking fonts-noto-mono (20171026-2) ...
# Selecting previously unselected package libcupsimage2:amd64.
# Preparing to unpack .../30-libcupsimage2_2.2.7-1ubuntu2.8_amd64.deb ...
# Unpacking libcupsimage2:amd64 (2.2.7-1ubuntu2.8) ...
# Selecting previously unselected package libijs-0.35:amd64.
# Preparing to unpack .../31-libijs-0.35_0.35-13_amd64.deb ...
# Unpacking libijs-0.35:amd64 (0.35-13) ...
# Selecting previously unselected package libjbig2dec0:amd64.
# Preparing to unpack .../32-libjbig2dec0_0.13-6_amd64.deb ...
# Unpacking libjbig2dec0:amd64 (0.13-6) ...
# Selecting previously unselected package libgs9-common.
# Preparing to unpack .../33-libgs9-common_9.26~dfsg+0-0ubuntu0.18.04.14_all.deb ...
# Unpacking libgs9-common (9.26~dfsg+0-0ubuntu0.18.04.14) ...
# Selecting previously unselected package libgs9:amd64.
# Preparing to unpack .../34-libgs9_9.26~dfsg+0-0ubuntu0.18.04.14_amd64.deb ...
# Unpacking libgs9:amd64 (9.26~dfsg+0-0ubuntu0.18.04.14) ...
# Selecting previously unselected package ghostscript.
# Preparing to unpack .../35-ghostscript_9.26~dfsg+0-0ubuntu0.18.04.14_amd64.deb ...
# Unpacking ghostscript (9.26~dfsg+0-0ubuntu0.18.04.14) ...
# Selecting previously unselected package gsfonts.
# Preparing to unpack .../36-gsfonts_1%3a8.11+urwcyr1.0.7~pre44-4.4_all.deb ...
# Unpacking gsfonts (1:8.11+urwcyr1.0.7~pre44-4.4) ...
# Selecting previously unselected package libcupsfilters1:amd64.
# Preparing to unpack .../37-libcupsfilters1_1.20.2-0ubuntu3.1_amd64.deb ...
# Unpacking libcupsfilters1:amd64 (1.20.2-0ubuntu3.1) ...
# Setting up libgs9-common (9.26~dfsg+0-0ubuntu0.18.04.14) ...
# Setting up imagemagick-6-common (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Setting up fonts-droid-fallback (1:6.0.1r16-1.1) ...
# Setting up liblcms2-dev:amd64 (2.9-1ubuntu0.1) ...
# Setting up gsfonts (1:8.11+urwcyr1.0.7~pre44-4.4) ...
# Setting up libcairo-script-interpreter2:amd64 (1.15.10-2ubuntu0.1) ...
# Setting up poppler-data (0.4.8-2) ...
# Setting up libdjvulibre-text (3.5.27.1-8ubuntu0.4) ...
# Setting up gir1.2-freedesktop:amd64 (1.56.1-1) ...
# Setting up libxcb-shm0-dev:amd64 (1.13-2~ubuntu18.04) ...
# Setting up libmagickcore-6-arch-config:amd64 (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Setting up gir1.2-gdkpixbuf-2.0:amd64 (2.36.11-2) ...
# Setting up fonts-noto-mono (20171026-2) ...
# Setting up libcupsfilters1:amd64 (1.20.2-0ubuntu3.1) ...
# Setting up libcupsimage2:amd64 (2.2.7-1ubuntu2.8) ...
# Setting up liblqr-1-0:amd64 (0.4.2-2.1) ...
# Setting up libjbig2dec0:amd64 (0.13-6) ...
# Setting up libgdk-pixbuf2.0-dev (2.36.11-2) ...
# Setting up libpixman-1-dev:amd64 (0.34.0-2) ...
# Setting up gir1.2-rsvg-2.0:amd64 (2.40.20-2ubuntu0.2) ...
# Setting up libijs-0.35:amd64 (0.35-13) ...
# Setting up libmagickcore-6-headers (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Setting up libgs9:amd64 (9.26~dfsg+0-0ubuntu0.18.04.14) ...
# Setting up libwmf0.2-7:amd64 (0.2.8.4-12) ...
# Setting up libwmf-dev (0.2.8.4-12) ...
# Setting up libmagickcore-6.q16-3:amd64 (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Setting up liblqr-1-0-dev:amd64 (0.4.2-2.1) ...
# Setting up libcairo2-dev:amd64 (1.15.10-2ubuntu0.1) ...
# Setting up libdjvulibre21:amd64 (3.5.27.1-8ubuntu0.4) ...
# Setting up libmagickwand-6-headers (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Setting up libdjvulibre-dev:amd64 (3.5.27.1-8ubuntu0.4) ...
# Setting up librsvg2-dev:amd64 (2.40.20-2ubuntu0.2) ...
# Setting up ghostscript (9.26~dfsg+0-0ubuntu0.18.04.14) ...
# Setting up libmagickwand-6.q16-3:amd64 (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Setting up libmagickcore-6.q16-3-extra:amd64 (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Setting up libmagickcore-6.q16-dev:amd64 (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Setting up libmagickwand-6.q16-dev:amd64 (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Setting up libmagickwand-dev (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link

# %%
import os
import cv2
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from keras.layers import Dropout
from keras.layers import Flatten
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.utils import np_utils
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Input, UpSampling2D
from keras.models import Model
from keras.callbacks import TensorBoard

# %%
import zipfile  # unziping 
import glob  # finding image paths
import numpy as np  # creating numpy arrays
from skimage.io import imread  # reading images
from skimage.transform import resize  # resizing images
# 1. Unzip images
path = '/content/dataset.zip'
with zipfile.ZipFile(path, 'r') as zip_ref:
    zip_ref.extractall('/content/image_data')

# %% [markdown]
# ### **Converting images to .jpeg format from .tiff**

# %%
import matplotlib.pyplot as plt
from PIL import Image

os.makedirs('/content/jpg_data')

for files in  os.listdir("/content/image_data/shuffled"):
    im = Image.open('/content/image_data/shuffled/'+str(files))
    im.save('/content/jpg_data/'+str(files).replace(".tiff","")+'.jpeg')

# %% [markdown]
# ###**Data Augmentation**

# %%
from keras.preprocessing.image import ImageDataGenerator
from skimage import io
from PIL import Image

datagen = ImageDataGenerator(
            width_shift_range=0.2,  
            height_shift_range=0.2,           
            zoom_range=0.2)

image_directory = '/content/55/'
SIZE = 224
dataset = []
my_images = os.listdir(image_directory)
for i, image_name in enumerate(my_images):    
   if (image_name.split('.')[1] == 'jpg'):        
       image = io.imread(image_directory + image_name)        
       image = Image.fromarray(image, 'RGB')        
       image = image.resize((SIZE,SIZE)) 
       dataset.append(np.array(image))
x = np.array(dataset)
i = 0
for batch in datagen.flow(x, batch_size=16,
                          save_to_dir='/content/jpg_data/',
                          save_prefix='u55_155t',
                          save_format='jpeg'):    
  i += 1    
  if i > 20:        
     break

# %% [markdown]
# ###**Resizing all images into the same size**

# %%
os.makedirs('/content/processed_img')

for fil in  os.listdir("/content/jpg_data"):
    img=cv2.imread('/content/jpg_data/'+str(fil))
    #img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img2=255-img
    img2=cv2.resize(img2, (128, 128))
    cv2.imwrite("/content/processed_img/"+str(fil), img2)

# %% [markdown]
# ### **Adding Impulse noise**

# %%
from wand.image import Image
#os.makedirs("/content/noisy_dataset")
for fil in  os.listdir("/content/processed_img"):
    img = cv2.imread('/content/processed_img/'+str(fil))
    with Image() as img:
      img.read(filename = '/content/processed_img/'+str(fil))
      img.noise("impulse")
      plt.imshow(img)
      img.save(filename = '/content/noisy_dataset/'+str(fil))

# %%
fig = plt.figure(figsize=(10,7))
img1 = cv2.imread('/content/processed_img/u16_010t03.jpeg')
ax1 = fig.add_subplot(121)
ax1.imshow(img1)
img2 = cv2.imread('/content/noisy_dataset/u16_010t03.jpeg')
ax2 = fig.add_subplot(122)
ax2.imshow(img2)

# %% [markdown]
# ###**Classifying X and y for train-test split**

# %%
images=[]
noisy_images=[]
for files in os.listdir('/content/processed_img/'):
  img=cv2.imread('/content/processed_img/'+files,0)/255
  img=cv2.resize(img,(128,128))
  img.shape=(128,128,1)
  images.append(img)

for files in os.listdir('/content/noisy_dataset/'):
  img=cv2.imread('/content/noisy_dataset/'+files,0)/255
  img=cv2.resize(img,(128,128))
  img.shape=(128,128,1)
  noisy_images.append(img)
images=np.array(images)
noisy_images=np.array(noisy_images)

# %% [markdown]
# ### **Train test split**

# %%
X_train, X_test, y_train, y_test = train_test_split(noisy_images, images, test_size=0.2, random_state=42)

# %%
X_train.shape
# Out:
# (1164, 128, 128, 1)

# %%
len(X_train)
# Out:
# 1164

# %%
len(X_test)
# Out:
# 292

# %% [markdown]
# ###**Denoising Autoencoder**

# %%
input_img = keras.Input(shape=(128, 128, 1))
#encoder
conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
conv2 = Conv2D(16, (3, 3), activation='relu', padding='same')(pool1)
pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
conv3 = Conv2D(8, (3, 3), activation='relu', padding='same')(pool2)

#decoder
conv4 = Conv2D(8, (3, 3), activation='relu', padding='same')(conv3)
up1 = UpSampling2D((2,2))(conv4)
conv5 = Conv2D(16, (3, 3), activation='relu', padding='same')(up1)
up2 = UpSampling2D((2,2))(conv5)
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(up2)

autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(loss='binary_crossentropy', optimizer = 'adam', metrics=['accuracy'])
autoencoder.summary()
# Out:
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 128, 128, 1)]     0
#
#  conv2d_42 (Conv2D)          (None, 128, 128, 32)      320
#
#  max_pooling2d_14 (MaxPoolin  (None, 64, 64, 32)       0
#  g2D)
#
#  conv2d_43 (Conv2D)          (None, 64, 64, 16)        4624
#
#  max_pooling2d_15 (MaxPoolin  (None, 32, 32, 16)       0
#  g2D)
#
#  conv2d_44 (Conv2D)          (None, 32, 32, 8)         1160
#
#  conv2d_45 (Conv2D)          (None, 32, 32, 8)         584
#
#  up_sampling2d_14 (UpSamplin  (None, 64, 64, 8)        0
#  g2D)
#
#  conv2d_46 (Conv2D)          (None, 64, 64, 16)        1168
#
#  up_sampling2d_15 (UpSamplin  (None, 128, 128, 16)     0
#  g2D)
#
#  conv2d_47 (Conv2D)          (None, 128, 128, 1)       145
#
# =================================================================
# Total params: 8,001
# Trainable params: 8,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10,batch_size=75)
# Out:
# Epoch 1/10
# 16/16 [==============================] - 26s 2s/step - loss: 0.6909 - accuracy: 0.5057 - val_loss: 0.6765 - val_accuracy: 0.6542
# Epoch 2/10
# 16/16 [==============================] - 26s 2s/step - loss: 0.5988 - accuracy: 0.6536 - val_loss: 0.3809 - val_accuracy: 0.6542
# Epoch 3/10
# 16/16 [==============================] - 26s 2s/step - loss: 0.3451 - accuracy: 0.6536 - val_loss: 0.3061 - val_accuracy: 0.6542
# Epoch 4/10
# 16/16 [==============================] - 26s 2s/step - loss: 0.2882 - accuracy: 0.6536 - val_loss: 0.2706 - val_accuracy: 0.6542
# Epoch 5/10
# 16/16 [==============================] - 26s 2s/step - loss: 0.2567 - accuracy: 0.6536 - val_loss: 0.2438 - val_accuracy: 0.6542
# Epoch 6/10
# 16/16 [==============================] - 26s 2s/step - loss: 0.2300 - accuracy: 0.6536 - val_loss: 0.2105 - val_accuracy: 0.6542
# Epoch 7/10
# 16/16 [==============================] - 26s 2s/step - loss: 0.1881 - accuracy: 0.6536 - val_loss: 0.1607 - val_accuracy: 0.6542
# Epoch 8/10
# 16/16 [==============================] - 26s 2s/step - loss: 0.1442 - accuracy: 0.6536 - val_loss: 0.1294 - val_accuracy: 0.6545
# Epoch 9/10
# 16/16 [==============================] - 26s 2s/step - loss: 0.1212 - accuracy: 0.6553 - val_loss: 0.1148 - val_accuracy: 0.6573
# Epoch 10/10
# 16/16 [==============================] - 26s 2s/step - loss: 0.1109 - accuracy: 0.6571 - val_loss: 0.1074 - val_accuracy: 0.6581

# %%
decoded_imgs = autoencoder.predict(X_test)

n = 4
plt.figure(figsize=(15, 10))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(X_test[i].reshape(128, 128))
    #plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i].reshape(128, 128))
    #plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
autoencoder.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=20, batch_size=100)
# Out:
# Epoch 1/20
# 12/12 [==============================] - 25s 2s/step - loss: 0.6685 - accuracy: 0.6081 - val_loss: 0.5874 - val_accuracy: 0.6542
# Epoch 2/20
# 12/12 [==============================] - 24s 2s/step - loss: 0.4204 - accuracy: 0.6536 - val_loss: 0.3501 - val_accuracy: 0.6542
# Epoch 3/20
# 12/12 [==============================] - 24s 2s/step - loss: 0.3137 - accuracy: 0.6536 - val_loss: 0.2891 - val_accuracy: 0.6542
# Epoch 4/20
# 12/12 [==============================] - 24s 2s/step - loss: 0.2753 - accuracy: 0.6536 - val_loss: 0.2627 - val_accuracy: 0.6542
# Epoch 5/20
# 12/12 [==============================] - 24s 2s/step - loss: 0.2531 - accuracy: 0.6536 - val_loss: 0.2431 - val_accuracy: 0.6542
# Epoch 6/20
# 12/12 [==============================] - 24s 2s/step - loss: 0.2337 - accuracy: 0.6536 - val_loss: 0.2196 - val_accuracy: 0.6542
# Epoch 7/20
# 12/12 [==============================] - 24s 2s/step - loss: 0.1984 - accuracy: 0.6536 - val_loss: 0.1706 - val_accuracy: 0.6542
# Epoch 8/20
# 12/12 [==============================] - 24s 2s/step - loss: 0.1537 - accuracy: 0.6536 - val_loss: 0.1408 - val_accuracy: 0.6542
# Epoch 9/20
# 12/12 [==============================] - 24s 2s/step - loss: 0.1360 - accuracy: 0.6536 - val_loss: 0.1316 - val_accuracy: 0.6542
# Epoch 10/20
# 12/12 [==============================] - 24s 2s/step - loss: 0.1263 - accuracy: 0.6540 - val_loss: 0.1201 - val_accuracy: 0.6564
# Epoch 11/20
# 12/12 [==============================] - 24s 2s/step - loss: 0.1136 - accuracy: 0.6570 - val_loss: 0.1080 - val_accuracy: 0.6585
# Epoch 12/20
# 12/12 [==============================] - 24s 2s/step - loss: 0.1051 - accuracy: 0.6580 - val_loss: 0.1021 - val_accuracy: 0.6589
# Epoch 13/20
# 12/12 [==============================] - 24s 2s/step - loss: 0.0999 - accuracy: 0.6583 - val_loss: 0.0980 - val_accuracy: 0.6590
# Epoch 14/20
# 12/12 [==============================] - 24s 2s/step - loss: 0.0961 - accuracy: 0.6585 - val_loss: 0.0948 - val_accuracy: 0.6592
# Epoch 15/20
# 12/12 [==============================] - 24s 2s/step - loss: 0.0932 - accuracy: 0.6586 - val_loss: 0.0921 - val_accuracy: 0.6593
# Epoch 16/20
# 12/12 [==============================] - 24s 2s/step - loss: 0.0910 - accuracy: 0.6587 - val_loss: 0.0903 - val_accuracy: 0.6594
# Epoch 17/20
# 12/12 [==============================] - 24s 2s/step - loss: 0.0892 - accuracy: 0.6588 - val_loss: 0.0888 - val_accuracy: 0.6595
# Epoch 18/20
# 12/12 [==============================] - 24s 2s/step - loss: 0.0878 - accuracy: 0.6588 - val_loss: 0.0875 - val_accuracy: 0.6595
# Epoch 19/20
# 12/12 [==============================] - 26s 2s/step - loss: 0.0867 - accuracy: 0.6589 - val_loss: 0.0865 - val_accuracy: 0.6595
# Epoch 20/20
# 12/12 [==============================] - 25s 2s/step - loss: 0.0857 - accuracy: 0.6589 - val_loss: 0.0856 - val_accuracy: 0.6596

# %%
decoded_imgs = autoencoder.predict(X_test)

n = 4
plt.figure(figsize=(15, 10))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(X_test[i].reshape(128, 128))
    #plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i].reshape(128, 128))
    #plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
autoencoder.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=25, batch_size=75)
# Out:
# Epoch 1/25
# 16/16 [==============================] - 26s 2s/step - loss: 0.4934 - accuracy: 0.6535 - val_loss: 0.3693 - val_accuracy: 0.6542
# Epoch 2/25
# 16/16 [==============================] - 25s 2s/step - loss: 0.3180 - accuracy: 0.6536 - val_loss: 0.2752 - val_accuracy: 0.6542
# Epoch 3/25
# 16/16 [==============================] - 25s 2s/step - loss: 0.2522 - accuracy: 0.6536 - val_loss: 0.2228 - val_accuracy: 0.6542
# Epoch 4/25
# 16/16 [==============================] - 25s 2s/step - loss: 0.1906 - accuracy: 0.6536 - val_loss: 0.1562 - val_accuracy: 0.6542
# Epoch 5/25
# 16/16 [==============================] - 25s 2s/step - loss: 0.1432 - accuracy: 0.6536 - val_loss: 0.1332 - val_accuracy: 0.6542
# Epoch 6/25
# 16/16 [==============================] - 25s 2s/step - loss: 0.1280 - accuracy: 0.6536 - val_loss: 0.1226 - val_accuracy: 0.6542
# Epoch 7/25
# 16/16 [==============================] - 25s 2s/step - loss: 0.1177 - accuracy: 0.6543 - val_loss: 0.1122 - val_accuracy: 0.6571
# Epoch 8/25
# 16/16 [==============================] - 25s 2s/step - loss: 0.1083 - accuracy: 0.6572 - val_loss: 0.1052 - val_accuracy: 0.6583
# Epoch 9/25
# 16/16 [==============================] - 25s 2s/step - loss: 0.1029 - accuracy: 0.6577 - val_loss: 0.1008 - val_accuracy: 0.6586
# Epoch 10/25
# 16/16 [==============================] - 25s 2s/step - loss: 0.0988 - accuracy: 0.6581 - val_loss: 0.0971 - val_accuracy: 0.6589
# Epoch 11/25
# 16/16 [==============================] - 25s 2s/step - loss: 0.0951 - accuracy: 0.6583 - val_loss: 0.0936 - val_accuracy: 0.6591
# Epoch 12/25
# 16/16 [==============================] - 25s 2s/step - loss: 0.0919 - accuracy: 0.6585 - val_loss: 0.0908 - val_accuracy: 0.6593
# Epoch 13/25
# 16/16 [==============================] - 25s 2s/step - loss: 0.0891 - accuracy: 0.6587 - val_loss: 0.0882 - val_accuracy: 0.6595
# Epoch 14/25
# 16/16 [==============================] - 25s 2s/step - loss: 0.0869 - accuracy: 0.6588 - val_loss: 0.0862 - val_accuracy: 0.6596
# Epoch 15/25
# 16/16 [==============================] - 25s 2s/step - loss: 0.0851 - accuracy: 0.6589 - val_loss: 0.0847 - val_accuracy: 0.6596
# Epoch 16/25
# 16/16 [==============================] - 25s 2s/step - loss: 0.0836 - accuracy: 0.6590 - val_loss: 0.0832 - val_accuracy: 0.6597
# Epoch 17/25
# 16/16 [==============================] - 25s 2s/step - loss: 0.0823 - accuracy: 0.6591 - val_loss: 0.0820 - val_accuracy: 0.6597
# Epoch 18/25
# 16/16 [==============================] - 25s 2s/step - loss: 0.0812 - accuracy: 0.6591 - val_loss: 0.0810 - val_accuracy: 0.6598
# Epoch 19/25
# 16/16 [==============================] - 25s 2s/step - loss: 0.0803 - accuracy: 0.6591 - val_loss: 0.0803 - val_accuracy: 0.6598
# Epoch 20/25
# 16/16 [==============================] - 25s 2s/step - loss: 0.0796 - accuracy: 0.6592 - val_loss: 0.0795 - val_accuracy: 0.6598
# Epoch 21/25
# 16/16 [==============================] - 25s 2s/step - loss: 0.0789 - accuracy: 0.6592 - val_loss: 0.0789 - val_accuracy: 0.6599
# Epoch 22/25
# 16/16 [==============================] - 25s 2s/step - loss: 0.0783 - accuracy: 0.6592 - val_loss: 0.0786 - val_accuracy: 0.6599
# Epoch 23/25
# 16/16 [==============================] - 25s 2s/step - loss: 0.0779 - accuracy: 0.6593 - val_loss: 0.0780 - val_accuracy: 0.6599
# Epoch 24/25
# 16/16 [==============================] - 25s 2s/step - loss: 0.0775 - accuracy: 0.6593 - val_loss: 0.0776 - val_accuracy: 0.6599
# Epoch 25/25
# 16/16 [==============================] - 25s 2s/step - loss: 0.0770 - accuracy: 0.6593 - val_loss: 0.0772 - val_accuracy: 0.6599

# %%
decoded_imgs = autoencoder.predict(X_test)

n = 4
plt.figure(figsize=(15, 10))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(X_test[i].reshape(128, 128))
    #plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i].reshape(128, 128))
    #plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
autoencoder.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=40,batch_size=100)
# Out:
# Epoch 1/40
# 12/12 [==============================] - 25s 2s/step - loss: 0.6169 - accuracy: 0.6480 - val_loss: 0.4354 - val_accuracy: 0.6542
# Epoch 2/40
# 12/12 [==============================] - 25s 2s/step - loss: 0.3650 - accuracy: 0.6536 - val_loss: 0.3258 - val_accuracy: 0.6542
# Epoch 3/40
# 12/12 [==============================] - 24s 2s/step - loss: 0.3028 - accuracy: 0.6536 - val_loss: 0.2787 - val_accuracy: 0.6542
# Epoch 4/40
# 12/12 [==============================] - 25s 2s/step - loss: 0.2642 - accuracy: 0.6536 - val_loss: 0.2475 - val_accuracy: 0.6542
# Epoch 5/40
# 12/12 [==============================] - 25s 2s/step - loss: 0.2287 - accuracy: 0.6536 - val_loss: 0.2040 - val_accuracy: 0.6542
# Epoch 6/40
# 12/12 [==============================] - 24s 2s/step - loss: 0.1819 - accuracy: 0.6536 - val_loss: 0.1588 - val_accuracy: 0.6542
# Epoch 7/40
# 12/12 [==============================] - 24s 2s/step - loss: 0.1472 - accuracy: 0.6536 - val_loss: 0.1374 - val_accuracy: 0.6542
# Epoch 8/40
# 12/12 [==============================] - 25s 2s/step - loss: 0.1328 - accuracy: 0.6536 - val_loss: 0.1289 - val_accuracy: 0.6542
# Epoch 9/40
# 12/12 [==============================] - 25s 2s/step - loss: 0.1265 - accuracy: 0.6537 - val_loss: 0.1242 - val_accuracy: 0.6543
# Epoch 10/40
# 12/12 [==============================] - 25s 2s/step - loss: 0.1221 - accuracy: 0.6539 - val_loss: 0.1195 - val_accuracy: 0.6548
# Epoch 11/40
# 12/12 [==============================] - 25s 2s/step - loss: 0.1165 - accuracy: 0.6554 - val_loss: 0.1126 - val_accuracy: 0.6576
# Epoch 12/40
# 12/12 [==============================] - 24s 2s/step - loss: 0.1091 - accuracy: 0.6574 - val_loss: 0.1062 - val_accuracy: 0.6583
# Epoch 13/40
# 12/12 [==============================] - 25s 2s/step - loss: 0.1033 - accuracy: 0.6577 - val_loss: 0.1009 - val_accuracy: 0.6586
# Epoch 14/40
# 12/12 [==============================] - 25s 2s/step - loss: 0.0986 - accuracy: 0.6580 - val_loss: 0.0968 - val_accuracy: 0.6588
# Epoch 15/40
# 12/12 [==============================] - 25s 2s/step - loss: 0.0950 - accuracy: 0.6582 - val_loss: 0.0938 - val_accuracy: 0.6590
# Epoch 16/40
# 12/12 [==============================] - 25s 2s/step - loss: 0.0921 - accuracy: 0.6585 - val_loss: 0.0912 - val_accuracy: 0.6592
# Epoch 17/40
# 12/12 [==============================] - 25s 2s/step - loss: 0.0898 - accuracy: 0.6586 - val_loss: 0.0891 - val_accuracy: 0.6593
# Epoch 18/40
# 12/12 [==============================] - 25s 2s/step - loss: 0.0879 - accuracy: 0.6587 - val_loss: 0.0875 - val_accuracy: 0.6594
# Epoch 19/40
# 12/12 [==============================] - 25s 2s/step - loss: 0.0863 - accuracy: 0.6588 - val_loss: 0.0859 - val_accuracy: 0.6595
# Epoch 20/40
# 12/12 [==============================] - 25s 2s/step - loss: 0.0849 - accuracy: 0.6589 - val_loss: 0.0847 - val_accuracy: 0.6596
# Epoch 21/40
# 12/12 [==============================] - 25s 2s/step - loss: 0.0838 - accuracy: 0.6590 - val_loss: 0.0836 - val_accuracy: 0.6597
# Epoch 22/40
# 12/12 [==============================] - 25s 2s/step - loss: 0.0828 - accuracy: 0.6590 - val_loss: 0.0827 - val_accuracy: 0.6597
# Epoch 23/40
# 12/12 [==============================] - 25s 2s/step - loss: 0.0820 - accuracy: 0.6591 - val_loss: 0.0820 - val_accuracy: 0.6597
# Epoch 24/40
# 12/12 [==============================] - 25s 2s/step - loss: 0.0813 - accuracy: 0.6591 - val_loss: 0.0813 - val_accuracy: 0.6598
# Epoch 25/40
# 12/12 [==============================] - 25s 2s/step - loss: 0.0807 - accuracy: 0.6591 - val_loss: 0.0808 - val_accuracy: 0.6598
# Epoch 26/40
# 12/12 [==============================] - 25s 2s/step - loss: 0.0801 - accuracy: 0.6592 - val_loss: 0.0803 - val_accuracy: 0.6598
# Epoch 27/40
# 12/12 [==============================] - 25s 2s/step - loss: 0.0796 - accuracy: 0.6592 - val_loss: 0.0797 - val_accuracy: 0.6599
# Epoch 28/40
# 12/12 [==============================] - 25s 2s/step - loss: 0.0791 - accuracy: 0.6592 - val_loss: 0.0793 - val_accuracy: 0.6599
# Epoch 29/40
# 12/12 [==============================] - 25s 2s/step - loss: 0.0787 - accuracy: 0.6592 - val_loss: 0.0789 - val_accuracy: 0.6599
# Epoch 30/40
# 12/12 [==============================] - 25s 2s/step - loss: 0.0783 - accuracy: 0.6592 - val_loss: 0.0785 - val_accuracy: 0.6599
# Epoch 31/40
# 12/12 [==============================] - 25s 2s/step - loss: 0.0780 - accuracy: 0.6593 - val_loss: 0.0782 - val_accuracy: 0.6599
# Epoch 32/40
# 12/12 [==============================] - 25s 2s/step - loss: 0.0776 - accuracy: 0.6593 - val_loss: 0.0778 - val_accuracy: 0.6599
# Epoch 33/40
# 12/12 [==============================] - 25s 2s/step - loss: 0.0774 - accuracy: 0.6593 - val_loss: 0.0775 - val_accuracy: 0.6600
# Epoch 34/40
# 12/12 [==============================] - 25s 2s/step - loss: 0.0770 - accuracy: 0.6593 - val_loss: 0.0772 - val_accuracy: 0.6600
# Epoch 35/40
# 12/12 [==============================] - 25s 2s/step - loss: 0.0767 - accuracy: 0.6593 - val_loss: 0.0770 - val_accuracy: 0.6600
# Epoch 36/40
# 12/12 [==============================] - 25s 2s/step - loss: 0.0765 - accuracy: 0.6593 - val_loss: 0.0768 - val_accuracy: 0.6600
# Epoch 37/40
# 12/12 [==============================] - 25s 2s/step - loss: 0.0762 - accuracy: 0.6593 - val_loss: 0.0765 - val_accuracy: 0.6600
# Epoch 38/40
# 12/12 [==============================] - 25s 2s/step - loss: 0.0760 - accuracy: 0.6593 - val_loss: 0.0763 - val_accuracy: 0.6600
# Epoch 39/40
# 12/12 [==============================] - 25s 2s/step - loss: 0.0758 - accuracy: 0.6593 - val_loss: 0.0760 - val_accuracy: 0.6600
# Epoch 40/40
# 12/12 [==============================] - 25s 2s/step - loss: 0.0756 - accuracy: 0.6594 - val_loss: 0.0759 - val_accuracy: 0.6600

# %%
decoded_imgs = autoencoder.predict(X_test)

n = 4
plt.figure(figsize=(15, 10))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(X_test[i].reshape(128, 128))
    #plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i].reshape(128, 128))
    #plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
autoencoder.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50,batch_size=75)
# Out:
# Epoch 1/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.4977 - accuracy: 0.6399 - val_loss: 0.3922 - val_accuracy: 0.6542
# Epoch 2/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.3383 - accuracy: 0.6536 - val_loss: 0.2936 - val_accuracy: 0.6542
# Epoch 3/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.2649 - accuracy: 0.6536 - val_loss: 0.2272 - val_accuracy: 0.6542
# Epoch 4/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.1895 - accuracy: 0.6536 - val_loss: 0.1471 - val_accuracy: 0.6542
# Epoch 5/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.1322 - accuracy: 0.6536 - val_loss: 0.1229 - val_accuracy: 0.6542
# Epoch 6/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.1201 - accuracy: 0.6536 - val_loss: 0.1181 - val_accuracy: 0.6542
# Epoch 7/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.1166 - accuracy: 0.6536 - val_loss: 0.1153 - val_accuracy: 0.6543
# Epoch 8/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.1137 - accuracy: 0.6539 - val_loss: 0.1121 - val_accuracy: 0.6550
# Epoch 9/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.1099 - accuracy: 0.6551 - val_loss: 0.1077 - val_accuracy: 0.6566
# Epoch 10/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.1047 - accuracy: 0.6568 - val_loss: 0.1019 - val_accuracy: 0.6582
# Epoch 11/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0991 - accuracy: 0.6578 - val_loss: 0.0971 - val_accuracy: 0.6587
# Epoch 12/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0948 - accuracy: 0.6583 - val_loss: 0.0933 - val_accuracy: 0.6592
# Epoch 13/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0912 - accuracy: 0.6586 - val_loss: 0.0901 - val_accuracy: 0.6594
# Epoch 14/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0885 - accuracy: 0.6588 - val_loss: 0.0879 - val_accuracy: 0.6595
# Epoch 15/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0864 - accuracy: 0.6589 - val_loss: 0.0860 - val_accuracy: 0.6596
# Epoch 16/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0848 - accuracy: 0.6590 - val_loss: 0.0845 - val_accuracy: 0.6597
# Epoch 17/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0834 - accuracy: 0.6590 - val_loss: 0.0832 - val_accuracy: 0.6597
# Epoch 18/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0822 - accuracy: 0.6591 - val_loss: 0.0820 - val_accuracy: 0.6598
# Epoch 19/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0812 - accuracy: 0.6591 - val_loss: 0.0813 - val_accuracy: 0.6598
# Epoch 20/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0803 - accuracy: 0.6592 - val_loss: 0.0802 - val_accuracy: 0.6598
# Epoch 21/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0794 - accuracy: 0.6592 - val_loss: 0.0795 - val_accuracy: 0.6599
# Epoch 22/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0787 - accuracy: 0.6592 - val_loss: 0.0788 - val_accuracy: 0.6599
# Epoch 23/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0781 - accuracy: 0.6593 - val_loss: 0.0783 - val_accuracy: 0.6599
# Epoch 24/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0775 - accuracy: 0.6593 - val_loss: 0.0777 - val_accuracy: 0.6599
# Epoch 25/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0770 - accuracy: 0.6593 - val_loss: 0.0772 - val_accuracy: 0.6600
# Epoch 26/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0765 - accuracy: 0.6593 - val_loss: 0.0766 - val_accuracy: 0.6600
# Epoch 27/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0760 - accuracy: 0.6593 - val_loss: 0.0762 - val_accuracy: 0.6600
# Epoch 28/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0755 - accuracy: 0.6594 - val_loss: 0.0757 - val_accuracy: 0.6600
# Epoch 29/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0751 - accuracy: 0.6594 - val_loss: 0.0755 - val_accuracy: 0.6600
# Epoch 30/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0748 - accuracy: 0.6594 - val_loss: 0.0750 - val_accuracy: 0.6600
# Epoch 31/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0744 - accuracy: 0.6594 - val_loss: 0.0747 - val_accuracy: 0.6601
# Epoch 32/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0742 - accuracy: 0.6594 - val_loss: 0.0744 - val_accuracy: 0.6601
# Epoch 33/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0739 - accuracy: 0.6594 - val_loss: 0.0742 - val_accuracy: 0.6601
# Epoch 34/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0737 - accuracy: 0.6594 - val_loss: 0.0741 - val_accuracy: 0.6601
# Epoch 35/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0735 - accuracy: 0.6594 - val_loss: 0.0739 - val_accuracy: 0.6601
# Epoch 36/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0733 - accuracy: 0.6594 - val_loss: 0.0736 - val_accuracy: 0.6601
# Epoch 37/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0731 - accuracy: 0.6594 - val_loss: 0.0734 - val_accuracy: 0.6601
# Epoch 38/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0730 - accuracy: 0.6594 - val_loss: 0.0733 - val_accuracy: 0.6601
# Epoch 39/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0728 - accuracy: 0.6594 - val_loss: 0.0731 - val_accuracy: 0.6601
# Epoch 40/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0727 - accuracy: 0.6594 - val_loss: 0.0730 - val_accuracy: 0.6601
# Epoch 41/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0726 - accuracy: 0.6595 - val_loss: 0.0729 - val_accuracy: 0.6601
# Epoch 42/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0725 - accuracy: 0.6595 - val_loss: 0.0728 - val_accuracy: 0.6601
# Epoch 43/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0724 - accuracy: 0.6595 - val_loss: 0.0727 - val_accuracy: 0.6601
# Epoch 44/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0723 - accuracy: 0.6595 - val_loss: 0.0728 - val_accuracy: 0.6601
# Epoch 45/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0722 - accuracy: 0.6595 - val_loss: 0.0725 - val_accuracy: 0.6601
# Epoch 46/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0720 - accuracy: 0.6595 - val_loss: 0.0724 - val_accuracy: 0.6601
# Epoch 47/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0720 - accuracy: 0.6595 - val_loss: 0.0723 - val_accuracy: 0.6601
# Epoch 48/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0719 - accuracy: 0.6595 - val_loss: 0.0724 - val_accuracy: 0.6601
# Epoch 49/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0718 - accuracy: 0.6595 - val_loss: 0.0722 - val_accuracy: 0.6601
# Epoch 50/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.0717 - accuracy: 0.6595 - val_loss: 0.0722 - val_accuracy: 0.6601

# %%
decoded_imgs = autoencoder.predict(X_test)

n = 4
plt.figure(figsize=(15, 10))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(X_test[i].reshape(128, 128))
    #plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i].reshape(128, 128))
    #plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
